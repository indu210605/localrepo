# %% [markdown]
# <a href="https://colab.research.google.com/github/indu210605/localrepo/blob/main/Sunflower.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image =cv2.imread("/content/sunflower.jpg")

# %%
image_rgb = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

plt.imshow(image_rgb)
plt.title("original image")
plt.show()
plt.axis
# Out:
# <function matplotlib.pyplot.axis(arg: 'tuple[float, float, float, float] | bool | str | None' = None, /, *, emit: 'bool' = True, **kwargs) -> 'tuple[float, float, float, float]'>

# %%
gray=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
plt.imshow(gray, cmap="gray")
plt.title("grayscale image")
plt.axis("off")
plt.show()

# %%
resized =cv2.resize(image_rgb,(300,300))
plt.imshow(resized)
plt.title("resized image")
plt.axis("off")
plt.show()
#

# %%
blurred =cv2.GaussianBlur(image_rgb,(11,11),0)
plt.imshow(blurred)
plt.title("blurred image")
plt.axis("off")
plt.show()

# %%
edges =cv2.Canny(gray,100,200)
plt.imshow(edges,cmap="gray")
plt.title("edges image")
plt.axis("off")
plt.show()

# %%
_, thresh = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
plt.imshow(thresh,cmap="gray")
plt.title("thresholded image")
plt.axis("off")
plt.show()
